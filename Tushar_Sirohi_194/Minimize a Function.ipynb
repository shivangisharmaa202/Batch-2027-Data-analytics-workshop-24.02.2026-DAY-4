# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Minimize%20a%20Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import minimize

def func(x):
    return x**2 + 4*x + 4

result = minimize(func, 0)

print("Minimum Value:", result.fun)
print("Value of x at minimum:", result.x)
# Out:
# Minimum Value: 0.0
# Value of x at minimum: [-2.00000002]
