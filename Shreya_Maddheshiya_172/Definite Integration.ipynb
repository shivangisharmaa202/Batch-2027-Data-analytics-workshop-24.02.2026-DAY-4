# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Definite%20Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import integrate

def func(x):
    return x**2

result, error = integrate.quad(func, 0, 3)

print("Integration Result:", result)
print("Estimated Error:", error)
# Out:
# Integration Result: 9.000000000000002
# Estimated Error: 9.992007221626411e-14
